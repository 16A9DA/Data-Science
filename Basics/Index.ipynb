# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Creating index
new_index = np.arange(0,1000)

# %%
np.random.shuffle(new_index)

# %%
df["new_index"] = new_index
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  new_index
# 0                    none          72             72             74        747
# 1               completed          69             90             88        924
# 2                    none          90             95             93        956
# 3                    none          47             57             44        600
# 4                    none          76             78             75          9

# %%
#set_index
df.set_index("new_index",inplace=True)
df.head()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 747        female        group B           bachelor's degree      standard
# 924        female        group C                some college      standard
# 956        female        group B             master's degree      standard
# 600          male        group A          associate's degree  free/reduced
# 9            male        group C                some college      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 747                          none          72             72             74
# 924                     completed          69             90             88
# 956                          none          90             95             93
# 600                          none          47             57             44
# 9                            none          76             78             75

# %%
# sorting by index
df.sort_index(ascending=True,inplace=True)
df.head()
# Out:
#            gender race/ethnicity parental level of education     lunch  \
# new_index
# 0          female        group C                some college  standard
# 1            male        group D                some college  standard
# 2            male        group C                 high school  standard
# 3            male        group B                some college  standard
# 4          female        group C            some high school  standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 0                            none          71             81             80
# 1                            none          40             42             38
# 2                            none          88             89             86
# 3                       completed          88             85             76
# 4                            none          47             54             53
