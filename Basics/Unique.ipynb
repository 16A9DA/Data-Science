# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv',encoding_errors='ignore')

# %%
df['Company'].unique()
df['Inches'].unique()
len(df['Inches'].unique())
# Out:
# 18

# %%
# exludes nan/null

df["Company"].nunique()
# gives len
# Out:
# 19
